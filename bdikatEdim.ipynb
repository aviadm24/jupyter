# %% [markdown]
# <a href="https://colab.research.google.com/github/aviadm24/jupyter/blob/master/bdikatEdim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# ['.config', 'sample_data']

# %%
# !wget "https://raw.githubusercontent.com/aviadm24/jupyter/master/edim/IMG_20201222_095559.jpg"
# Out:
# --2020-12-31 23:24:23--  https://raw.githubusercontent.com/aviadm24/jupyter/master/edim/IMG_20201222_095559.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3452361 (3.3M) [image/jpeg]
# Saving to: ‘IMG_20201222_095559.jpg’
#
# IMG_20201222_095559 100%[===================>]   3.29M  --.-KB/s    in 0.1s
#
# 2020-12-31 23:24:23 (28.0 MB/s) - ‘IMG_20201222_095559.jpg’ saved [3452361/3452361]

# %%
import os
items = os.listdir('/content')
for item in items:
  if item.endswith("jpg"):
    img_name = item
print(img_name)
# Out:
# IMG_20201222_095559.jpg

# %%
import cv2
import numpy as np

# %matplotlib inline
#The line above is necesary to show Matplotlib's plots inside a Jupyter Notebook
from matplotlib import pyplot as plt
#Show the image with matplotlib


img = cv2.imread('/content/'+img_name)
plt.figure(figsize = (50,30))
# plt.imshow(random.rand(8, 90), interpolation='nearest')
plt.imshow(img)
plt.show()

color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# img_hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# mask1 = cv2.inRange(img_hsv, (0,50,20), (5,255,255))
# mask2 = cv2.inRange(img_hsv, (175,50,20), (180,255,255))
# mask = cv2.bitwise_or(mask1, mask2 )
# croped = cv2.bitwise_and(img, img, mask=mask)

# plt.imshow(mask)
# plt.show()


# plt.imshow(croped)
# plt.show()

# cv2.imshow("mask", mask)
# cv2.imshow("croped", croped)
# cv2.waitKey()
